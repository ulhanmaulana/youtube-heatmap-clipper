# %%
# %%bash
# # Install FFmpeg (required for video processing)
# echo "📦 Installing FFmpeg..."
# apt-get update -qq
# apt-get install -y -qq ffmpeg
#
# # Verify installation
# echo -e "\n✅ FFmpeg installed successfully!"
# ffmpeg -version | head -n 1
# Out:
# 📦 Installing FFmpeg...
#
# ✅ FFmpeg installed successfully!
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Clone repository if not already cloned
if not os.path.exists('youtube-heatmap-clipper'):
    print("🤖 Cloning repository...")
    # !git clone https://github.com/ulhanmaulana/youtube-heatmap-clipper.git
    print("✅ Repository cloned!")
else:
    print("✅ Repository already exists")

# Change to project directory
# %cd youtube-heatmap-clipper
print("\n📂 Current directory:", os.getcwd())
# Out:
# 🤖 Cloning repository...
# Cloning into 'youtube-heatmap-clipper'...
# remote: Enumerating objects: 424, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 424 (delta 52), reused 70 (delta 28), pack-reused 328 (from 1)
# Receiving objects: 100% (424/424), 10.89 MiB | 16.85 MiB/s, done.
# Resolving deltas: 100% (180/180), done.
# ✅ Repository cloned!
# /content/youtube-heatmap-clipper
#
# 📂 Current directory: /content/youtube-heatmap-clipper

# %%
# %%bash
# # Install Python dependencies
# echo "📦 Installing Python packages..."
# pip install -q -r requirements.txt
#
# echo -e "\n✅ All dependencies installed!"
# echo -e "\n📋 Installed packages:"
# pip list | grep -E "(Flask|yt-dlp|pyngrok|faster-whisper|requests)"
# Out:
# 📦 Installing Python packages...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 111.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 74.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 100.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 32.1 MB/s eta 0:00:00
#
# ✅ All dependencies installed!
#
# 📋 Installed packages:
# faster-whisper                           1.2.1
# Flask                                    3.1.3
# pyngrok                                  8.0.0
# requests                                 2.32.4
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# yt-dlp                                   2026.3.17
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.

# %%
# Optional: Set your own ngrok token
# Uncomment dan ganti dengan token kamu jika ada
import os
os.environ['NGROK_AUTH_TOKEN'] = '37s2ID5Pco29lF4zq02uNihVvDk_7ZFcCUZ3TbXM4QsBjcoXd'

print("✅ Ngrok token setup (using default or custom)")
# Out:
# ✅ Ngrok token setup (using default or custom)

# %%
# Run the web app
# This will start the Flask server with ngrok tunnel
# !python webapp.py
# Out:
# 🔍 Detected Google Colab environment
#
# ============================================================
# 🌐 Public URL: NgrokTunnel: "https://unpunishingly-postthoracic-jay.ngrok-free.dev" -> "http://localhost:5000"
# ============================================================
#
# <IPython.core.display.HTML object>
#
# 🎬 YouTube Heatmap Clipper is starting...
#  * Serving Flask app 'webapp'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [25/Apr/2026 20:56:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:56:21] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:56:21] "GET /static/app.js HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:56:22] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Apr/2026 20:57:12] "POST /api/preview HTTP/1.1" 400 -
# Reading YouTube heatmap data...
#   [OK] Found 100 raw markers
#   [DEBUG] Score range: 0.000 to 1.000
#   [DEBUG] Current threshold: 0.25
#   [DEBUG] Markers above threshold: 14/100
# 127.0.0.1 - - [25/Apr/2026 20:57:21] "POST /api/scan HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:58:14] "POST /api/clip HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:58:14] "GET /api/job/e185c4d3cb74 HTTP/1.1" 200 -
# [Clip 1] Processing segment (211s - 265s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 20:58:16] "GET /api/job/e185c4d3cb74 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] od5j0c_zP48: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# 127.0.0.1 - - [25/Apr/2026 20:58:18] "GET /api/job/e185c4d3cb74 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:58:50] "POST /api/clip HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:58:50] "GET /api/job/e4d9456e02e4 HTTP/1.1" 200 -
# [Clip 1] Processing segment (686s - 739s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 20:58:53] "GET /api/job/e4d9456e02e4 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] od5j0c_zP48: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# 127.0.0.1 - - [25/Apr/2026 20:58:55] "GET /api/job/e4d9456e02e4 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:59:35] "POST /api/preview HTTP/1.1" 400 -
# 127.0.0.1 - - [25/Apr/2026 20:59:38] "POST /api/clip HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 20:59:38] "GET /api/job/a938e7ad8a96 HTTP/1.1" 200 -
# Reading YouTube heatmap data...
# 127.0.0.1 - - [25/Apr/2026 20:59:40] "GET /api/job/a938e7ad8a96 HTTP/1.1" 200 -
#   [OK] Found 100 raw markers
#   [DEBUG] Score range: 0.000 to 1.000
#   [DEBUG] Current threshold: 0.25
#   [DEBUG] Markers above threshold: 44/100
# [Clip 1] Processing segment (2499s - 2565s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 20:59:42] "GET /api/job/a938e7ad8a96 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# [Clip 2] Processing segment (91s - 157s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 20:59:44] "GET /api/job/a938e7ad8a96 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# [Clip 3] Processing segment (2056s - 2123s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 20:59:46] "GET /api/job/a938e7ad8a96 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# [Clip 4] Processing segment (975s - 1041s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 20:59:48] "GET /api/job/a938e7ad8a96 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# 127.0.0.1 - - [25/Apr/2026 20:59:50] "GET /api/job/a938e7ad8a96 HTTP/1.1" 200 -
# Reading YouTube heatmap data...
#   [OK] Found 100 raw markers
#   [DEBUG] Score range: 0.000 to 1.000
#   [DEBUG] Current threshold: 0.25
#   [DEBUG] Markers above threshold: 44/100
# 127.0.0.1 - - [25/Apr/2026 21:00:09] "POST /api/scan HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 21:00:19] "POST /api/clip HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 21:00:20] "GET /api/job/49277eef3e56 HTTP/1.1" 200 -
# Reading YouTube heatmap data...
# 127.0.0.1 - - [25/Apr/2026 21:00:22] "GET /api/job/49277eef3e56 HTTP/1.1" 200 -
#   [OK] Found 100 raw markers
#   [DEBUG] Score range: 0.000 to 1.000
#   [DEBUG] Current threshold: 0.25
#   [DEBUG] Markers above threshold: 44/100
# [Clip 1] Processing segment (2499s - 2565s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 21:00:24] "GET /api/job/49277eef3e56 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# [Clip 2] Processing segment (91s - 157s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 21:00:26] "GET /api/job/49277eef3e56 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# [Clip 3] Processing segment (2056s - 2123s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 21:00:28] "GET /api/job/49277eef3e56 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# [Clip 4] Processing segment (975s - 1041s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 21:00:30] "GET /api/job/49277eef3e56 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# 127.0.0.1 - - [25/Apr/2026 21:00:32] "GET /api/job/49277eef3e56 HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 21:00:43] "POST /api/clip HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 21:00:44] "GET /api/job/6fe9e51c4ebc HTTP/1.1" 200 -
# [Clip 1] Processing segment (2499s - 2565s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 21:00:46] "GET /api/job/6fe9e51c4ebc HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# 127.0.0.1 - - [25/Apr/2026 21:00:48] "GET /api/job/6fe9e51c4ebc HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 21:00:58] "POST /api/clip HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Apr/2026 21:00:59] "GET /api/job/0a3fef31ddc3 HTTP/1.1" 200 -
# [Clip 1] Processing segment (2499s - 2565s, padding 10s)
# 127.0.0.1 - - [25/Apr/2026 21:01:01] "GET /api/job/0a3fef31ddc3 HTTP/1.1" 200 -
# Failed to generate this clip.
# Error details: ERROR: [youtube] -j1Bgw8oAJM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
#
# 127.0.0.1 - - [25/Apr/2026 21:01:03] "GET /api/job/0a3fef31ddc3 HTTP/1.1" 200 -
# Exception ignored in atexit callback: <function shutdown at 0x7b209d1c0400>
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 2259, in shutdown
#     h.acquire()
#   File "/usr/lib/python3.12/logging/__init__.py", line 973, in acquire
#     self.lock.acquire()
# KeyboardInterrupt:
